# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # Valorant Champions Tour (VCT) 2024: How do headshot and agent pick rates affect team win rates in the 2024 VCT Playoffs?
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# [CRediT taxonomy of contributions](https://credit.niso.org) for reference
#
# - Keilani Li: Project administration, Writing - original draft, Data curation, Software, Analysis, Methodology
# - Bryan Lu:
# - Hazel Liang: Analysis, Visualization, Writing-original draft, Software, Methodology
# - Lillian Tran:
# - Luis Quintanilla:

# %% [markdown]
# ## Research Question

# %% [markdown]
# To what extent do headshot percentage and agent pick rates predict team win rates across regions in the 2024 VCT playoffs, and does the strength of these predictors vary significantly between regions?
#
# We will approach our research question using variables such as agent pick rates, match results, region labels, and headshot percentages gathered from players who participated in the 2024 VCT playoffs.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# ### Introduction
#
# Developed and released in 2020 by Riot Games, VALORANT is a free-to-play 5v5 tactical shooter game with 28 playable agents divided into 4 different roles–duelist, initiator, controller, sentinel–as of February 2026. Players select “agents” prior to the start of the match, with teams switching between attacking and defending “sites” halfway through the game. “Site” refers to an area on the map where the attacking team needs to plant the objective, otherwise known as the “spike,” and the defending team needs to prevent it from being planted or defuse it before it explodes after a certain amount of time. “Agents” are playable characters, each with unique abilities that complement the different roles:
# - Duelists: Excel at “entry fragging.” Basically, they are agents that are best known for initial fights and entering sites. Their abilities are often movement abilities or defensive utilities meant for getting kills to help their team enter the site and plant the bomb.
# - Initiators: Information gatherers. These agents' utilities help their team find where the enemies are positioning or even hiding. Additionally, their kit comes with abilities that help the team further fight enemies at an advantage, such as flashes or stuns. Flashing refers to blinding enemies, and stunning refers to a short debuff that impairs movement, gunfire rate, and shaky camera movement for the player to simulate dizziness. Both of these factors may increase a player’s probability of winning a gunfight with their opponent.
# - Controllers: Strategic agents that utilize their abilities to assist teammates and manipulate the battlefield, which involves the map, enemy positions, and actions. These abilities include walls and smokes, which help block out enemies and help their team take space on site. Walls and smokes are temporary barriers that block the enemy’s line of sight, but not a solid barrier, so they can still walk through them or enemies can also wait for them to disappear after a certain amount of time.
# - Sentinels: Site defenders and bombsite anchors. Sentinels are the agents who help secure the sites for their team. They excel at stalling enemy pushes–whether it be delaying an enemy attack from behind or delaying the enemy team from taking full control of a site.
#
# The goal of the game is to win 13 rounds by attacking and defending your site using gunplay and abilities. A core mechanic in gunplay is the headshot. While each gun deals a different amount of damage to the head, something unique to Valorant is that when both teams are on equal buy, meaning they have the same amount of money, most guns only require a single bullet to the head to instantly kill an opponent. This makes headshot percentage a key measurement of individual mechanical skill.
#
# VALORANT Champion Tour (VCT) is an annual tournament hosted by Riot Games. It features four regional leagues, Americas, EMEA, Pacific, and China. VCT events are divided into regional leagues and international leagues. Regional leagues refer to the four regions as mentioned previously while international leagues refer to Masters or Champions events. In other words, the international leagues consist of top teams that won their regional games and the one team that wins is considered the best team in the world as of that year. Since there are many different levels of tournaments and stages, for this project, we will be focusing on VCT Challengers playoff games from 2024. We decided to leave out games from previous stages since the playoffs stage involves top teams, where winners advance to the grand finals.
#
# From a viewer's perspective, each region has different play styles. Regions like EMEA may play very strategically while other regions like to ‘run it down,’ or in other words, play more aggressively. With 18 unique guns to buy from and 28 different agents to choose from, we thought it would be interesting to explore how headshot rates and agent pick rates affect win percentages across different regions.
#
# This research matters because VCT playoffs represent the highest level of competitive Valorant. The prize pools for these international events exceed a million dollars annually. With any kind of sport, successful teams will attract huge sponsorship deals and brand partners. Understanding certain features that establish a successful team can help improve future games and coaching decisions. It might even shine light on any adjustments necessary for improving game balance by showing us whether certain playstyles or agents have a possible disproportionate competitive advantage. In addition, regional playstyle differences may reveal how gameplay is tied to cultural differences and practice environments.
#
# ### Prior Work
#
# One study that has been done related to our topic is Valorant Analysis: A Comparative Study of Machine Learning Models<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). As suggested by the title, the author compared the performances between different machine learning models trained on Valorant data. More specifically, they compared these models to determine which is the best at revealing underlying patterns and predicting outcomes in a "high-stakes gaming environment." The author used a Kaggle dataset on a player's first 1000 Valorant games (not their own games). They performed basic EDA and created data visualizations to understand visual patterns across different variables like agent pick distributions, rank distribution, map frequency, wins/losses, and KDA (kills, deaths, assists) metrics. Afterwards, they trained an XGB (eXtreme Gradient Boosting) model and an RF (Random Forest) model. When comparing metrics&mdash;accuracy, precision, recall, F1-score, class 0 performance, weight average&mdash;between the two models, they found that the RF model performed slightly better in terms of precision and F1-score.
#
# Another study, titled Valorant VCT Challengers 2024 Analysis, has actually been done on a dataset we may consider using<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). The author first preprocessed the data by renaming columns, converting data types, and handling missing values. Going into EDA, they looked into region and agent distribution, and then they visualized selected columns as a density histogram. Afterward, they looked into the top 1% of players with the highest rating in the tournament and top 1% of agents played.
#
# The last study we were able to find related to our topic is the VCT 2024 Agent Composition Analysis<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). This analysis has also been done on a different dataset we consider using for this project. The author preprocessed their data through feature engineering, renaming columns, and did some basic exploration where they looked at descriptive summary statistics for: number of matches played per tournament, stage distribution, match type distribution, and number of matches played per map. They also visualized win rates between agent picks, maps, and they applied a regression model to see if meta agent picks have an impact on win probability and a prediction model on whether map and agent pick influences win probability. Lastly, they created a recommendation list of agents based on win rate and pick rate for each map, which was very interesting to look at.
#
# Each of the three studies mentioned above explores individual performance and agent compositions separately. None have examined how the interactions between mechanical skill (headshot percentage) and strategic choices (agent compositions) vary across the different regions in VCT. Additionally, the existing studies primarily focus on descriptive analysis rather than predictive modeling and do not specifically analyze any regional playstyle differences. Our project differs from other studies as it:
# 1. Examines the interaction between headshot percentage and agent picks
# 2. Compares how results vary across the four major VCT regions and to what extent
# 3. Uses playoff data from two consecutive years
#
# A limitation we found from the first prior work is related to the dataset they used for analysis. From Kaggle, they used a dataset titled My First 1000 Valorant Games, where the dataset author used the data gathered from their own account. With that said, the analyses that were done in the article are not generalizable to the Valorant population as the machine learning models were applied to analyze one player’s account out of millions of others. They also did not explain how their findings were important and focused more on how the models they used differed from one another in terms of metrics. It was also a bit unclear what variables were being used as inputs for the machine learning, especially more so if you do not know how to read code. We will address this kind of limitation by being clear about information that might be missing from our dataset and how they affect our conclusion findings, and also creating markdown cells to explain our work in detail so our reader does not feel lost.
#
# Another limitation can be found in the second prior work, where their data visualization in comparing 4 different columns–rating, KAST (kills, assists, survived, traded), headshot percentage, clutch success percentage–overlaps one another. This makes the graph hard for the reader to interpret even when there’s a short caption explaining all but one plot appears normally distributed. We would address this type of limitation in our project by making sure our plots are easily understandable and so we can reduce cognitive overload.
#
# The last limitation we found is in the third study, which also relates to some of their data visualizations. For example, when looking into the win rates per agent, the author chose to give their bar graph a diverging color scheme when it is unnecessary. This is considered a limitation because it may contribute to cognitive overload since the colors do not provide any significant meaning. The interpretation of the graph would be the same if all the bars were one single color. This color scheme is more suited for visualizations such as a correlation heatmap, which is a graph they do have in their study. But for a bar graph, a diverging color scheme is not needed. We will address this type of limitation in our project by using colors wisely in our data visualizations especially if it can help convey more information to our audience.
#
# ### References
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) https://medium.com/@sanketangchekar/valorant-analysis-a-comparative-study-of-machine-learning-models-fa3f2866335e
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) https://www.kaggle.com/code/blackdragonk333/valorant-vct-challengers-2024-analysis-eda
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) https://www.kaggle.com/code/setsuna00/vct-2024-agent-composition-analysis

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that while headshot percentage positively correlates with win rates across all regions, the strength of this relationship will vary across different regions and their playstyles. We further hypothesize that agent pick rates moderate this relationship, such that utility-heavy compositions reduce the marginal impact of headshot percentage on team win rates.
#
# As mentioned in our background, each of the four regions has different play styles. Our hypothesis is that regions that favor utility-reliant agents (such as EMEA) may show a weaker headshot-win rate correlation compared to regions that play more duelist-heavy “run it down” compositions. Although headshot percentage can be an indicator of a winning team, utility-heavy compositions can also garner kills without relying solely on raw aim, potentially mitigating the impact of headshot percentage differences.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: Valorant Champion Tour 2021-2025
#   - Link to the dataset: https://www.kaggle.com/datasets/ryanluong1/valorant-champion-tour-2021-2023-data?select=vct_2025
#   - Number of observations: 373,564 (prior to cleaning)
#   - Number of variables: 46
#   - Description of the variables most relevant to this project
#     - ``headshot_percentage``
#     - ``pick rate``
#     - ``agent``
#     - ``map``
#     - ``outcome``
#     - ``match_result``
#   - Descriptions of any shortcomings this dataset has with respect to the project
#     - Missing data due to uncontrollable factors, such as missing names and certain situations not occurring (e.g, 1v1 gunfights or operator kills)

# %% [markdown]
# ### Wrangling: Valorant Champion Tour 2021-2025 data
#
# This dataset includes statistics for both matches and players from the Valorant Champions Tour (VCT) between 2021 and 2025, but the focus is on the 2024 VCT.
#
# Key variables from this dataset are ``pick rate``, ``headshot_percentage``, ``agent``, ``map``, ``outcome``, and ``match_result``. Pick rate is a strong indicator of an agent’s popularity among Valorant players. While it may not automatically mean a higher win rate, it can indicate a comfort pick for certain players since teams have preferences for their desired agents over others. It is also significant to note which side an agent is on because that can determine when specific agents are better used. Headshot percentage is a key stat to analyze with context, as some agents are better utilized for attack compared to defense and vice versa. Thus, the outcome can be explained as to why headshot percentages are higher for agents on a particular side. The map provides information on the kind of battlefield used for every match in the dataset. Knowing the names of the agents is crucial for understanding the value they bring to the battlefield. This ties to the pick rates because different playstyles fit each agent. Lastly, variables related to match wins, such as ``outcome`` and ``match_result``, are the most important statistics for our project since they are connected to whether teams win/lose rounds and ultimately the game as a whole.
#
# From reading the data shown on this dataset, it is important to note the key limitations that this dataset presents. The first concern to address is the missing stats from matches played in China. This can be attributed to Chinese-hosted events not having APIs (Application Programming Interface) available for post-game statistics. Thus, multiple variables from Chinese-hosted events are missing and cannot be used for analysis. However, there are still missing values even when events are not hosted in China. This may be due to how events play out during the game. For example, null values may appear in a “2k” column, representing a player getting 2 kills, because it is possible for that player to not get 2 kills in one round. Another instance may include null values for “Overtime Scores” because it is possible for a match to not go into overtime. To go into overtime in Valorant means that the score is 12-12 and one team must win 2 consecutive rounds in a row in order to win (e.g a team will win the entire game if the match score is 14-12).

# %% [markdown]
# #### Importing & cleaning

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# For the purpose of keeping our report as short as possible, we will not include the wrangling steps where we checked for missingness in our dataset. To see more code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on, we will simply load the processed data for further analysis and do a couple data conversions.
#
# More importantly, we will prepare for the EDA process by first defining what we mean by win rate. Since the data does not explicitly have this data for us, we will have to do some feature engineering. Luckily, we have what we need to make these calculations. We will be calculating headshot percentages as well as agent pick rates as a team and compare it to team win rates of a match.

# %%
# load processed data
## agents folder
agents_pick = pd.read_csv('data/02-processed/vct_both_2024_2025/vct_2024/agents_pick.csv')
teams_agents_pick = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/agents/teams_picked_agents.csv')

## ids folder
overview_clean = pd.read_csv('data/02-processed/vct_both_2024_2025/vct_2024/overview.csv')

## matches folder
scores = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/scores.csv')

## players_stats folder
players_stats = pd.read_csv("data/02-processed/vct_both_2024_2025/vct_2024/players_stats.csv")

# %%
# create function that converts percent strings into float values

def convert_percent_column(series, as_proportion=False):
    """
    purpose: converts pandas Series like '64%' into numeric
    
    params:
        series (pd.Series): column containing percentage strings
        as_proportion (bool): if True, returns proportion as a decimal (e.g 0.64 instead of 64)
    
    returns:
        pd.Series (float)
    """
    cleaned_series = (series.astype(str).str.strip().str.replace('%', '', regex = False))
    
    # convert
    numeric = pd.to_numeric(cleaned_series, errors='coerce')  
    
    if as_proportion:
        numeric = numeric / 100
        
    return numeric

# %%
# convert percentages column from object into float data types
overview_clean['Headshot %'] = convert_percent_column(
    overview_clean['Headshot %'],
    as_proportion = True
)

# since we will eventually look into agent pick rate, we will also convert the 'Pick Rate' column here
agents_pick['Pick Rate'] = convert_percent_column(
    agents_pick['Pick Rate'],
    as_proportion = True
)

# %%
# calculate headshot percentage as a team
playoffs_overview = overview_clean[overview_clean['Stage'] == 'Playoffs']

playoffs_overview = (
    playoffs_overview
    .groupby('Team')['Headshot %']
    .mean()
    .reset_index(name = 'avg_team_hs')
)

print(playoffs_overview.shape)
playoffs_overview.head()
# Out:
# (31, 2)
#               Team  avg_team_hs
# 0      100 Thieves     0.275740
# 1       All Gamers     0.300000
# 2  Bilibili Gaming     0.256000
# 3           Cloud9     0.306000
# 4              DRX     0.283436

# %%
unique_teams = playoffs_overview['Team'].unique()
print(unique_teams)

num_unique_teams = playoffs_overview['Team'].nunique()
print('\nNumber of unique teams:', num_unique_teams)
# Out:
# ['100 Thieves' 'All Gamers' 'Bilibili Gaming' 'Cloud9' 'DRX'
#  'Dragon Ranger Gaming' 'EDward Gaming' 'Evil Geniuses' 'FNATIC'
#  'FUT Esports' 'FunPlus Phoenix' 'G2 Esports' 'Gen.G' 'JDG Esports'
#  'KRÜ Esports' 'Karmine Corp' 'LEVIATÁN' 'LOUD' 'NRG Esports'
#  'Natus Vincere' 'Nova Esports' 'Paper Rex' 'Rex Regum Qeon' 'Sentinels'
#  'T1' 'Talon Esports' 'Team Heretics' 'Team Liquid' 'Team Secret'
#  'Team Vitality' 'Trace Esports']
#
# Number of unique teams: 31

# %%
team_region_mapping = {

    # Americas
    "Evil Geniuses": "Americas",
    "LOUD": "Americas",
    "NRG Esports": "Americas",
    "Sentinels": "Americas",
    "100 Thieves": "Americas",
    "Cloud9": "Americas",
    "G2 Esports": "Americas",
    "KRÜ Esports": "Americas",
    "LEVIATÁN": "Americas",

    # EMEA
    "FNATIC": "EMEA",
    "Karmine Corp": "EMEA",
    "Natus Vincere": "EMEA",
    "Team Heretics": "EMEA",
    "FUT Esports": "EMEA",
    "Team Liquid": "EMEA",
    "Team Vitality": "EMEA",

    # Pacific
    "Gen.G": "Pacific",
    "Paper Rex": "Pacific",
    "DRX": "Pacific",
    "T1": "Pacific",
    "Talon Esports": "Pacific",
    "Team Secret": "Pacific",
    "Rex Regum Qeon": "Pacific",

    # China
    "Dragon Ranger Gaming": "China",
    "EDward Gaming": "China",
    "FunPlus Phoenix": "China",
    "Trace Esports": "China",
    "All Gamers": "China",
    "Nova Esports": "China",
    "Bilibili Gaming": "China",
    "JDG Esports": "China",
}

len(team_region_mapping)
# Out:
# 31

# %%
playoffs_overview['Team_Region'] = playoffs_overview['Team'].map(team_region_mapping)
playoffs_overview.head()
# Out:
#               Team  avg_team_hs Team_Region
# 0      100 Thieves     0.275740    Americas
# 1       All Gamers     0.300000       China
# 2  Bilibili Gaming     0.256000       China
# 3           Cloud9     0.306000    Americas
# 4              DRX     0.283436     Pacific

# %% [markdown]
# Now that we have calculated the average headshot rate per team, we need to calculate each team's win rate of a match. We will need the ``scores`` dataframe to calculate this.

# %%
# calculate team win rate

# make long dataframe (one row per team per match)
playoffs_scores = scores[scores['Stage'] == 'Playoffs']
df = playoffs_scores.copy()

team_a = df[[
    "Tournament", "Stage", "Match Type",
    "Team A", "Match Result"
]].copy()

team_a.columns = [
    "Tournament", "Stage", "Match Type",
    "Team", "Match Result"
]

team_b = df[[
    "Tournament", "Stage", "Match Type",
    "Team B", "Match Result"
]].copy()

team_b.columns = [
    "Tournament", "Stage", "Match Type",
    "Team", "Match Result"
]

matches_long = pd.concat([team_a, team_b], ignore_index=True)

# determine who won the match
matches_long["Winner"] = matches_long["Match Result"].str.replace(
    " won", "", regex = False
)

matches_long["Win"] = (
    matches_long["Team"] == matches_long["Winner"]
).astype(int)

# aggregate to team level
team_record = (
    matches_long
    .groupby("Team")
    .agg(
        Matches_Played = ("Win", "count"),
        Wins = ("Win", "sum")
    )
    .reset_index()
)

team_record["Losses"] = (
    team_record["Matches_Played"] - team_record["Wins"]
)

team_record["Win_Rate"] = (
    team_record["Wins"] / team_record["Matches_Played"]
)

team_record = team_record.sort_values("Win_Rate", ascending = False)

print(team_record.shape)
team_record.head()
# Out:
# (31, 5)
#              Team  Matches_Played  Wins  Losses  Win_Rate
# 12          Gen.G              17    14       3  0.823529
# 6   EDward Gaming              15    12       3  0.800000
# 0     100 Thieves              11     7       4  0.636364
# 23      Sentinels              11     7       4  0.636364
# 26  Team Heretics              21    13       8  0.619048

# %% [markdown]
# Now, we can merge these dataframes together since it's easier to have everything in one place. But we are not done yet! We also need to calculate the agent pick rate for each team.

# %%
# merge what we have so far on team level (playoffs_overview and team_record)
playoffs_teams_merged = pd.merge(playoffs_overview, team_record, on = 'Team', how = 'inner')

print(playoffs_teams_merged.shape)
playoffs_teams_merged.head()
# Out:
# (31, 7)
#               Team  avg_team_hs Team_Region  Matches_Played  Wins  Losses  \
# 0      100 Thieves     0.275740    Americas              11     7       4
# 1       All Gamers     0.300000       China               2     0       2
# 2  Bilibili Gaming     0.256000       China               3     1       2
# 3           Cloud9     0.306000    Americas               2     0       2
# 4              DRX     0.283436     Pacific              10     3       7
#
#    Win_Rate
# 0  0.636364
# 1  0.000000
# 2  0.333333
# 3  0.000000
# 4  0.300000

# %%
teams_agents_pick.head()
# Out:
#                 Tournament     Stage           Match Type     Map Team  \
# 0  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 1  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 2  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 3  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 4  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
#
#     Agent  Total Wins By Map  Total Loss By Map  Total Maps Played
# 0    sova                  0                  1                  1
# 1  cypher                  0                  1                  1
# 2    omen                  0                  1                  1
# 3  breach                  0                  1                  1
# 4    neon                  0                  1                  1

# %%
# calculate average pick rate of agents for each team in playoffs stage

'''
procedure:
1) filter teams_agents_pick by playoffs stage
2) groupby team + agent & calc avg pick rate for each team-agent combo
3) pivot table to have teams as rows and agents as columns, w avg pick rate
'''

# filter by playoffs stage
teams_agents_pick = teams_agents_pick[teams_agents_pick['Stage'] == 'Playoffs']

# count agent picks
count_agent_picks = teams_agents_pick.groupby(["Team","Agent"]).size().reset_index(name="agent_picks")

# total maps per team
count_team_maps = teams_agents_pick.groupby("Team")["Map"].nunique().reset_index(name="total_maps")

# merge
playoffs_team_agent_picks = count_agent_picks.merge(count_team_maps, on="Team")

# calculate pick rate
playoffs_team_agent_picks["pick_rate"] = playoffs_team_agent_picks["agent_picks"] / playoffs_team_agent_picks["total_maps"]
playoffs_team_agent_picks.head()
# Out:
#           Team      Agent  agent_picks  total_maps  pick_rate
# 0  100 Thieves      astra            1           9   0.111111
# 1  100 Thieves  brimstone            6           9   0.666667
# 2  100 Thieves     cypher            8           9   0.888889
# 3  100 Thieves       fade           11           9   1.222222
# 4  100 Thieves      gekko           18           9   2.000000

# %%
# pivot table to have teams as rows and agents as columns, w avg pick rate

pivoted = playoffs_team_agent_picks.pivot(index="Team", columns="Agent", values="pick_rate").reset_index()
pivoted = pivoted.fillna(0.0)
pivoted.columns = [
    col if col == "Team" or col == "Agent" else f"{col}_pick_rate"
    for col in pivoted.columns
]

print(pivoted.shape)
pivoted.head()
# Out:
# (31, 25)
#               Team  astra_pick_rate  breach_pick_rate  brimstone_pick_rate  \
# 0      100 Thieves         0.111111          0.000000             0.666667
# 1       All Gamers         0.000000          0.666667             0.000000
# 2  Bilibili Gaming         0.000000          0.400000             0.200000
# 3           Cloud9         0.000000          0.250000             0.000000
# 4              DRX         0.000000          1.285714             0.857143
#
#    chamber_pick_rate  clove_pick_rate  cypher_pick_rate  deadlock_pick_rate  \
# 0           0.000000             0.00          0.888889            0.000000
# 1           0.000000             0.00          1.333333            0.333333
# 2           0.400000             0.00          0.600000            0.000000
# 3           0.000000             0.25          0.000000            0.000000
# 4           0.428571             0.00          2.571429            0.000000
#
# ...

# %%
# merge w playoffs_teams_merged to have final dataframe with all team-level stats + agent pick rates
final_df = pd.merge(playoffs_teams_merged, pivoted, on = 'Team', how = 'left')
final_df = final_df.rename(columns = str.lower)

# only get columns we need
final_df = final_df.drop(columns = ['matches_played', 'wins', 'losses'])

# %%
final_df[final_df.isna().any(axis = 1)]
# Out:
#                     team  avg_team_hs team_region  win_rate  astra_pick_rate  \
# 5   Dragon Ranger Gaming          NaN       China       0.4              0.0
# 20          Nova Esports          NaN       China       0.0              0.0
#
#     breach_pick_rate  brimstone_pick_rate  chamber_pick_rate  clove_pick_rate  \
# 5                0.2                  0.6                0.0              0.0
# 20               1.0                  0.0                0.0              0.0
#
#     cypher_pick_rate  ...  neon_pick_rate  omen_pick_rate  phoenix_pick_rate  \
# 5                2.4  ...             0.0             1.6                0.0
# 20               0.0  ...             0.0             1.0                0.0
#
#     raze_pick_rate  reyna_pick_rate  sage_pick_rate  skye_pick_rate  \
# 5              1.4              0.0             0.0             1.2
# 20             0.5              0.0             0.0             0.5
#
#     sova_pick_rate  viper_pick_rate  yoru_pick_rate
# ...

# %% [markdown]
# Unfortunately, we were unable to calculate the average team headshot rate for 2 teams from China. This may be due to missing information found within the dataset due to API statistics not being available from events that were hosted in China. Since null values cannot be used in statistical analysis, we will need to drop these teams from our analysis. When we draw conclusions from our analyses, we will make sure to consider this as a limitation.

# %%
final_df = final_df.dropna()

print(final_df.shape)
final_df.head()
# Out:
# (29, 28)
#               team  avg_team_hs team_region  win_rate  astra_pick_rate  \
# 0      100 Thieves     0.275740    Americas  0.636364         0.111111
# 1       All Gamers     0.300000       China  0.000000         0.000000
# 2  Bilibili Gaming     0.256000       China  0.333333         0.000000
# 3           Cloud9     0.306000    Americas  0.000000         0.000000
# 4              DRX     0.283436     Pacific  0.300000         0.000000
#
#    breach_pick_rate  brimstone_pick_rate  chamber_pick_rate  clove_pick_rate  \
# 0          0.000000             0.666667           0.000000             0.00
# 1          0.666667             0.000000           0.000000             0.00
# 2          0.400000             0.200000           0.400000             0.00
# 3          0.250000             0.000000           0.000000             0.25
# 4          1.285714             0.857143           0.428571             0.00
#
# ...

# %% [markdown]
# Great! Now we have our final dataframe which we will use for statistical analysis. For EDA purposes, we will also be creating a dataframe that contains information on the overall agent pick rate since we have just calculated team-level agent pick rates.

# %%
# filter by playoffs stage & all maps
playoffs_overall_agents_pick = agents_pick[(agents_pick['Stage'] == 'Playoffs') & (agents_pick['Map'] == 'All Maps')]

'''
procedure: 
1) find average pick rate per agent
2) sort in descending order
3) reset index so 'agent' is a column again
'''
playoffs_overall_agents_pick = playoffs_overall_agents_pick.groupby('Agent')[['Pick Rate']].mean().sort_values(by = 'Pick Rate', ascending = False).reset_index()

print(playoffs_overall_agents_pick.shape)
playoffs_overall_agents_pick.head()
# Out:
# (24, 2)
#     Agent  Pick Rate
# 0    omen   0.650260
# 1   viper   0.548442
# 2    raze   0.486494
# 3    sova   0.449091
# 4  cypher   0.417273

# %%
# categorizing agents by their role
role_mapping = {
    'reyna': 'duelist',
    'jett': 'duelist',
    'phoenix': 'duelist',
    'iso': 'duelist',
    'raze': 'duelist',
    'neon': 'duelist',
    'yoru': 'duelist',

    'omen': 'controller',
    'astra': 'controller',
    'brimstone': 'controller',
    'viper': 'controller',
    'harbor': 'controller',
    'clove': 'controller',
    
    'sova': 'initiator',
    'breach': 'initiator',
    'fade': 'initiator',
    'kayo': 'initiator',
    'gekko': 'initiator',
    'skye': 'initiator',

    'cypher': 'sentinel',
    'killjoy': 'sentinel',
    'sage': 'sentinel',
    'chamber': 'sentinel',
    'deadlock': 'sentinel'
}

len(role_mapping) # output: 24
# Out:
# 24

# %%
# map roles to agents
playoffs_overall_agents_pick['Agent Role'] = playoffs_overall_agents_pick['Agent'].map(role_mapping)
playoffs_overall_agents_pick.head()
# Out:
#     Agent  Pick Rate  Agent Role
# 0    omen   0.650260  controller
# 1   viper   0.548442  controller
# 2    raze   0.486494     duelist
# 3    sova   0.449091   initiator
# 4  cypher   0.417273    sentinel

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# ### Results Summary
#
# Based on the findings of our data visualizations, there are key takeaways from the explanations. Headshot percentage is not a strong indicator of high win rates. There is an inverse relationship with win rate decreasing as the headshot percentage increased. In the 2024 VCT Playoffs, the most popular agent used across all maps is Omen. Omen also happens to be the popular choice among agents who identify as a controller. As for the popular choice for duelist, initiator, and sentinel, they are Raze, Sova, and Cypher respectively. The boxplots with distribution by region have notable observations. For the first one with headshot percentage, EMEA teams have a wider range of headshot percentages as a whole, whereas teams from Americas have closer headshot percentages. The distribution for win rate percentage shows teams from Americas having a wide range of win rate percentages despite having closer headshot percentages. Teams from Pacific have closer win rate percentages, but EMEA teams have higher average win rates. The two distributions show certain disconnect between headshot rates and win rates. When analyzing the headshot rate distribution solely by the 10 agents with the highest pick rate, no drastic difference in headshot percentage exists as the average is around the same range. This proves a weak correlation between pick rate and headshot percentage.

# %% [markdown]
# Now let's actually get into our EDA. We will first look into agents and how their pick rates are distributed for the VCT 2024 season.

# %%
# scatterplot: team avg headshot rate vs match win rate
fig = sns.regplot(playoffs_teams_merged, x = 'avg_team_hs', y = 'Win_Rate', ci = None)

plt.title('How does average team headshot rate compare to their match win rate?')
plt.xlabel('Average team headshot rate')
plt.ylabel('Match win rate')
# Out:
# Text(0, 0.5, 'Match win rate')

# %% [markdown]
# Based on the scatterplot, it seems there is a weak, negative correlation between a team's average headshot rate and their match win rate. This is especially interesting to see since you would expect the chances of winning a match to increase if the team's headshot rate is high on average. Some outliers to point out here would be between the 0.28 and 0.30 headshot rate mark. While these headshot rates are low, these teams were able to have a high match win rate of around 0.8 or higher.
#
# The next step is to see how agent pick rates are distributed throughout the Playoffs stage.

# %%
# plot agent & their respective pick rate
fig = sns.barplot(data = playoffs_overall_agents_pick, x = 'Pick Rate', y = 'Agent', errorbar = None)
plt.title('Playoffs Stage: Omen has highest pick rate across all maps')
# Out:
# Text(0.5, 1.0, 'Playoffs Stage: Omen has highest pick rate across all maps')

# %% [markdown]
# Here, we have generated a bar plot comparing each agent with their overall pick rate across all maps during the Playoffs stage. At first glance, we can see that the highest agent pick rate is Omen while the lowest pick rate is Iso. But what does this mean? To reiterate from earlier, a controller's utility kit helps manipulate site space while duelist's utility kit is known to help their team enter a site and take the first fights. So you might be wondering, why is Omen, a controller, picked more than Iso, a duelist?
#
# Since there are a lot of agents listed in the visualization, it may be easier to interpret pick rates categorized by role.

# %%
# filter so it's easier to plot by role
duelist_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'duelist']
initiator_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'initiator']
controller_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'controller']
sentinel_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'sentinel']

# create bar plots comparing agents & their respective pick rates, separated by their role
fig, axes = plt.subplots(2, 2, figsize = (16, 10))

# duelist
sns.barplot(
    data = duelist_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[0, 0]
)
axes[0, 0].set_title("Duelist")

# initiator
sns.barplot(
    data = initiator_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[0, 1]
)
axes[0, 1].set_title("Initiator")

# controller
sns.barplot(
    data = controller_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[1, 0]
)
axes[1, 0].set_title("Controller")

# sentinel
sns.barplot(
    data = sentinel_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[1, 1]
)
axes[1, 1].set_title("Sentinel")

plt.suptitle("Playoffs Stage: Overall Agent Pick Rate Across All Maps by Role", fontsize = 16)
plt.tight_layout()
plt.show()

# %% [markdown]
# When we think about the question we asked earlier, "why is Omen, a controller, picked more than Iso, a duelist?", it is also important to consider the distribution of roles in a team.
#
# A typical team composition may involve at least one agent from each role. Since there are four roles, it is easy to satisfy this type of composition and the last person's role can be flexible, which is why sometimes there may be two people playing the same role in a team. However, there are other instances where a team might play a composition of two duelists, two controllers, and one initiator, meaning that no one is playing a sentinel role for example. Of course, there are many variations.
#
# Going back to the question, the answer may simply be that Omen's utility provides more value to the team than Iso, and that a different duelist is picked instead.
#
# You might also wonder, can Omen and Iso both be picked for one team? The answer is yes, but that may depend on other agents that are picked for the team and also the map that is being played.

# %%
team_hs_region = playoffs_overview.copy()
team_hs_region = team_hs_region.dropna(subset=['avg_team_hs'])

plt.figure(figsize=(10, 6))
colors = {'Americas': 'red', 'EMEA': 'blue', 'Pacific': 'green', 'China': 'orange'}
sns.boxplot(data=team_hs_region, x='Team_Region', y='avg_team_hs', 
            hue='Team_Region', palette=list(colors.values()), legend=False)
sns.stripplot(data=team_hs_region, x='Team_Region', y='avg_team_hs',
              color='black', alpha=0.5, size=8, jitter=True)
plt.title('Headshot % Distribution by Region - VCT 2024 Playoffs')
plt.xlabel('Region')
plt.ylabel('Average Headshot %')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot - Headshot % Distribution by Region VCT 2024 Playoffs
# This boxplot shows the distribution of headshot percentage across the 4 regions (31 teams) that played in playoffs. Each box represents the middle 50% of that region and the middle line is the median. Each dot represents a team from that region.
#
# #### Observations
# - Americas (NA): This box appears to be tied with APAC for the smallest and lowest median. This means, the majority of players have very similar headshot percentages. The only difference is, Americas distribution is a bit wider and on the lower end.
# - China: This box is the second largest box and is also the second widest distribution next to EMEA. This box is unique as the median is very close to the end of the upper quartile.
# - Pacific (APAC): APAC's boxplot has the thinnest distribution meaning everyones headshot percentage is most similar in this region.
# - EMEA: EMEA's boxplot is the largest. Everyone's headshot percentage is vastly different from each other. If we look at the dots, all of them are a decent length apart. Every other region looks like at least one of their dots almost overlap.

# %%
team_wr_region = playoffs_teams_merged.copy()

plt.figure(figsize=(10, 6))

colors = {'Americas': 'red', 'EMEA': 'blue', 'Pacific': 'green', 'China': 'orange'}

sns.boxplot(
    data = team_wr_region, x = 'Team_Region', y = 'Win_Rate',
    hue = 'Team_Region', palette = list(colors.values()), legend = False
)
sns.stripplot(
    data = team_wr_region, x = 'Team_Region', y = 'Win_Rate',
    color = 'black', alpha = 0.5, size = 8, jitter = True
)

plt.title('Win Rate % Distribution by Region - VCT 2024 Playoffs')
plt.xlabel('Region')
plt.ylabel('Win Rate %')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot - Win Rate Distribution by Region VCT 2024 Playoffs
# This boxplot shows the distribution of win rate percentage across the 4 regions that played in playoffs. Each box represents the middle 50% of that region and the middle line is the median. Each dot represents a team from that region.
#
# #### Observations
# - Americas (NA): This box doesn't seem to match the headshot percentage box much, it has the biggest shift in terms of distribution (from most similar in headshot % to biggest gap in win rate %). In general, this region's win rate has the widest range compared to the other regions despite having
# the smallest range when it came to headshot percentage where it was neither worst or best (but could be considered worst if only looking at all regions' max headshot %).
# However, in this boxplot, we can see NA matches for worst at its lowest and for second best at its highest.
# - China: This box, when compared with the Pacific region, match their headshot counterpart a bit better. China has a wider range than Pacific in both, its lowest for both is noticeably worse
# than the pacific region's, and their highest is still slightly worse than the Pacific's best.
# - Pacific (APAC): As stated in China's observation, when compared, it's quite similar to the headshot boxplot. However, there are still a few differences, especially as despite having the thinnest
# distribution in headshots, and while still having the smallest range here, the distribution found here is still considerably larger compared to headshot distribution. You can also note                      that where they had their lowest headshot percentage be considerably better than EMEA's headshot percentage, their lowest win rate percentage here is tied with EMEA's lowest.
# - EMEA: EMEA here once again has their box's highest above that of the other region's. It, however, isn't the one with most distribution this time. Despite this, it's median still remains noticeably higher than the others, and in terms of lowest it's tied with Pacific, and both are considerably higher than both America's and China's tied lowest.
#
# Overall, comparing this to headshot %, the data shows us that there's some disconnect between who can more consistently get headshots and who wins. While the Americas is the most consistent region in headshot accuracy, that doesn't translate to win rate, as they suffer from the widest gap between their top and bottom-performing teams. On the other end, EMEA stands out as the most successful region, maintaining the highest median win rate and the highest win rate despite having the widest gap in terms of headshot percentage. It just ultimately shows that while aim can help provide an advantage or factor in terms of a victory, there's other potential factors (clutches, economy, team strategies/utility, or just generally more consistent mechanics) that should also be considered when looking into a
# team's winrate.

# %% [markdown]
# As a player, it is natural to wonder why certain agents are most frequently selected in professional play and whether higher pick rates are associated with stronger headshot percentages. In the following analysis, we examine both the popularity of agents and their performance distribution to better understand the relationship between the competitive meta and player-level performance trends.

# %%
# compute top 10 agents based on avg pick rate
top_pick = (
    agents_pick
    .groupby('Agent')['Pick Rate']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

# bar plot: top 10 picked agents
plt.figure(figsize=(10,6))
top_pick.plot(kind='bar')

plt.title("Top 10 Agents by Average Pick Rate")
plt.ylabel("Pick Rate (%)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The barplot shows the top 10 agents ranked by their average pick rate in professional VCT matches. As we can see, Omen and Viper have the highest pick rates, which suggests that they are highly favored in the current competitive meta. Of course, other agents such as Raze, Sova, and Cypher are also commonly selected in professional play.
#
# As players, this makes us wonder why these agents dominate the meta. Is it because of their abilities, team utility, or are there other reasons behind their popularity?

# %%
# convert headshot % col from object to float data type
players_stats['Headshot %'] = (
    players_stats['Headshot %']
    .str.replace('%','')
    .astype(float)
)

# identify top 10 played agents
top_agents = (
    players_stats['Agents']
    .value_counts()
    .head(10)
    .index
)

filtered = players_stats[
    players_stats['Agents'].isin(top_agents)
]

# boxplot: headshot % distribution by top 10 agents
plt.figure(figsize=(12,6))

sns.boxplot(
    data=filtered,
    x='Agents',
    y='Headshot %',
    hue='Agents',      
    palette='Set2',
    legend=False       
)

plt.xticks(rotation=45)
plt.title("Headshot % Distribution by Top 10 Agents")
plt.show()

# %% [markdown]
# This boxplot shows the distribution of headshot percentages for the top 10 most frequently picked agents. Most agents have median headshot percentages around the 20% to 30% range. Interestingly, the distributions look fairly similar across agents, although some agents display slightly wider variability. This suggests that headshot percentage does not differ dramatically across these agents. Therefore, higher pick rates may not necessarily correspond to higher headshot accuracy.
#
# If headshot accuracy is similar across agents, perhaps agent popularity is influenced more by team strategy and utility rather than raw aim.
#
# These observations indicate that while certain agents dominate the professional meta in terms of selection frequency, agent popularity may not necessarily be driven by headshot percentage alone but could also depend on team strategy, utility value, or map-specific advantages.

# %% [markdown]
# ### First Analysis You Did - Give it a better title
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %% [markdown]
# As mentioned in our Wrangling section, we will be using ``final_df`` for statistical modeling and testing.

# %%
# you can also delete this cell if you want, i just put it here for reference -keilani
# we will use this dataframe for this section
print(final_df.shape)
final_df.head()
# Out:
# (29, 28)
#               team  avg_team_hs team_region  win_rate  astra_pick_rate  \
# 0      100 Thieves     0.275740    Americas  0.636364         0.111111
# 1       All Gamers     0.300000       China  0.000000         0.000000
# 2  Bilibili Gaming     0.256000       China  0.333333         0.000000
# 3           Cloud9     0.306000    Americas  0.000000         0.000000
# 4              DRX     0.283436     Pacific  0.300000         0.000000
#
#    breach_pick_rate  brimstone_pick_rate  chamber_pick_rate  clove_pick_rate  \
# 0          0.000000             0.666667           0.000000             0.00
# 1          0.666667             0.000000           0.000000             0.00
# 2          0.400000             0.200000           0.400000             0.00
# 3          0.250000             0.000000           0.000000             0.25
# 4          1.285714             0.857143           0.428571             0.00
#
# ...

# %% [markdown]
# ### Multilinear Regression
#
# We prepared our dataframe for modeling by dropping the team name column since it's a unique identifier and would not be useful in the prediction modeling we're about to do. We also converted region names into dummy variables so that categories are binary encoded (i.e values of 0 or 1). We also used the parameter ``drop_first`` when creating these dummies. The purpose of this is to avoid perfect multicollinearity. When we create the model, our multilinear regression formula will use the Americas region as the baseline, meaning that there will still be a bias intercept to predict the win rate for America teams even if the data for it is not present in the dataframe itself.

# %%
# prepare data for modeling by dropping team col since it's an identifier & not useful for modeling
df_model = final_df.drop(columns = ['team'])

# convert region into dummy vars for modeling
df_model = pd.get_dummies(df_model, columns = ['team_region'], drop_first = True)
df_model.head()
# Out:
#    avg_team_hs  win_rate  astra_pick_rate  breach_pick_rate  \
# 0     0.275740  0.636364         0.111111          0.000000
# 1     0.300000  0.000000         0.000000          0.666667
# 2     0.256000  0.333333         0.000000          0.400000
# 3     0.306000  0.000000         0.000000          0.250000
# 4     0.283436  0.300000         0.000000          1.285714
#
#    brimstone_pick_rate  chamber_pick_rate  clove_pick_rate  cypher_pick_rate  \
# 0             0.666667           0.000000             0.00          0.888889
# 1             0.000000           0.000000             0.00          1.333333
# 2             0.200000           0.400000             0.00          0.600000
# 3             0.000000           0.000000             0.25          0.000000
# 4             0.857143           0.428571             0.00          2.571429
#
#    deadlock_pick_rate  fade_pick_rate  ...  raze_pick_rate  reyna_pick_rate  \
# ...

# %% [markdown]
# From a previous analysis attempt using the dataframe that was created above (and which we also omitted from the notebook), we found that putting all columns for each agent yielded insignificant results (R-squared value of 1.000, infinite standard errors) and the model overfit. This result made sense since we were using more than 20 variables to compute win rate. To combat this, we decided to group agents by their role and run multilinear regression that way.

# %%
# group agents by their role & sum pick rates to get overall pick rate for each role, then add as new columns to new modeling dataframe
controllers = ['astra_pick_rate', 'brimstone_pick_rate', 'clove_pick_rate', 'omen_pick_rate', 'viper_pick_rate']
duelists = ['jett_pick_rate', 'raze_pick_rate', 'reyna_pick_rate', 'phoenix_pick_rate', 'neon_pick_rate', 'yoru_pick_rate', 'iso_pick_rate']
initiators = ['sova_pick_rate', 'skye_pick_rate', 'fade_pick_rate', 'gekko_pick_rate', 'breach_pick_rate', 'kayo_pick_rate']
sentinels = ['cypher_pick_rate', 'killjoy_pick_rate', 'sage_pick_rate', 'chamber_pick_rate', 'deadlock_pick_rate']

# create new dataframe for modeling
df_model2 = df_model[['avg_team_hs', 'win_rate', 'team_region_China', 'team_region_EMEA', 'team_region_Pacific']].copy()
df_model2['controller_pick_rate'] = df_model[controllers].sum(axis=1)
df_model2['duelist_pick_rate'] = df_model[duelists].sum(axis=1)
df_model2['initiator_pick_rate'] = df_model[initiators].sum(axis=1)
df_model2['sentinel_pick_rate'] = df_model[sentinels].sum(axis=1)

df_model2.head()
# Out:
#    avg_team_hs  win_rate  team_region_China  team_region_EMEA  \
# 0     0.275740  0.636364              False             False
# 1     0.300000  0.000000               True             False
# 2     0.256000  0.333333               True             False
# 3     0.306000  0.000000              False             False
# 4     0.283436  0.300000              False             False
#
#    team_region_Pacific  controller_pick_rate  duelist_pick_rate  \
# 0                False              4.000000           3.111111
# 1                False              1.333333           1.333333
# 2                False              1.800000           1.600000
# 3                False              2.000000           1.250000
# 4                 True              5.714286           4.142857
#
#    initiator_pick_rate  sentinel_pick_rate
# 0             5.666667            2.222222
# 1             2.000000            1.666667
# 2             2.200000            2.400000
# ...

# %%
# define X & y variables
X = df_model2.drop(columns = ['win_rate'])
y = df_model2['win_rate']

# ensure X is all float data types
X = X.astype(float)
X = sm.add_constant(X)

# fit OLS regression model & print summary
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               win_rate   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     9.200
# Date:                Mon, 16 Mar 2026   Prob (F-statistic):           2.97e-05
# Time:                        01:08:42   Log-Likelihood:                 19.501
# No. Observations:                  29   AIC:                            -21.00
# Df Residuals:                      20   BIC:                            -8.697
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.6692      0.323      2.072      0.051      -0.005       1.343
# ...

# %% [markdown]
# #### Multilinear Regression Results Breakdown
#
# As opposed to the other analysis attempt we described before creating this new modeling dataframe, the model summary here generated more meaningful results.
#
# Firstly, the model generated an R<sup>2</sup> value of 0.786 and an adjusted R<sup>2</sup> of 0.701. This means about 78% of the variance in team win rates can be explained by the model, and even after adjusting for the number of predictors, about 70% of the variance in team win rates can be explained by the model.
#
# In regards to our hypothesis, the model yielded a p-value of 0.039 which is less than our significance level of α = 0.05. This means that headshot rate is statistically significant in predicting win rates. However, it is also important to address the coefficient of average team headshot rates which is -2.43. A negative coefficient in this case means that, interestingly enough, an increase in headshot rate is associated with a decrease in win rate. This goes directly against our hypothesis that an increase in headshot would positively correlate with win rate.
#
# Additionally, when considering the p-values we got for each region, we can see that all region variables have a p-value greater than 0.05.
# - China p-value: 0.543 > 0.05
# - EMEA p-value: 0.698 > 0.05
# - Pacific p-value: 0.718 > 0.05
#
# In essence, there is no statistically significant difference in win rate between regions for the VCT 2024 playoffs dataset we generated. This also goes against our hypothesis in that regional playstyles may affect win outcomes.
#
# When looking at agent role result breakdowns, we found there to be no statistically significant evidence that team composition predicts win rate for this model given that the p-values for each role category were greater than our significance level of α = 0.05.
# - Controller p-value: 0.471
# - Duelist p-value: 0.469
# - Initiator p-value: 0.335
# - Sentinel p-value: 0.843

# %% [markdown]
# ### Second Analysis You Did - Give it a better title
#
# Some more words and stuff. Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context. Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model

# %% [markdown]
# ### PCA for dimensionality reduction
# Identifying Agent Composition Patterns in VCT Matches Using PCA

# %% [markdown]
# Based on our previous analysis, we examine whether agent selections form common composition patterns in VCT matches.
# To investigate this, we apply PCA to the agent pick rate variables.
# PCA helps reduce the dimensionality of the data and allows us to visualize potential composition patterns across matches.

# %%
# combine all agent pick rate variables
pick_cols = controllers + duelists + initiators + sentinels


picks = df_model[pick_cols]

# %%
# scale the data and keep the first two principal components
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler()
picks_scaled = scaler.fit_transform(picks)
pca = PCA(n_components=2)
pcs = pca.fit_transform(picks_scaled)

# %%
# create dataframe with PC1 and PC2
pca_df = pd.DataFrame(pcs, columns=['PC1', 'PC2'])

# Keep win rate
pca_df['win_rate'] = df_model['win_rate']

# show how much variance 
print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# Explained variance ratio: [0.39524996 0.12352055]

# %% [markdown]
# The explained variance ratio shows how much information is captured by each principal component. In our results, the first principal component (PC1) explains 39.5% of the variance, while the second principal component (PC2) explains 12.4%. Together, the first two components explain around 52% of the total variance in the dataset. This indicates that these two components represent a large portion of the variation in agent pick compositions across matches. Furthermore, this allows us to visualize the main composition patterns in a two-dimensional space.

# %%
# plot PCA result
plt.figure(figsize=(8,6))

sns.scatterplot(
    x='PC1',
    y='PC2',
    data=pca_df,
    hue='win_rate',
    palette='viridis'
)

plt.title("PCA of Agent Pick Rate Compositions")
plt.show()

# %% [markdown]
# The scatter plot shows the first two principal components based on agent pick rates. Each point represents a match and the color indicates the win rate. Matches that appear closer together have more similar compositions. Most of the points on PC2 fall between about -2 and 2, while PC1 spreads across a wider range from around -4 to 6. This suggests that PC1 has more variation in team compositions. The points are also spread out rather than forming clear clusters. Furthermore, this result indicates that teams use a variety of different compositions instead of one dominant strategy.

# %%
# get PCA loadings
loadings = pca.components_.T

loading_df = pd.DataFrame(
    loadings,
    index=pick_cols,
    columns=['PC1', 'PC2']
)

loading_df.head()
# Out:
#                           PC1       PC2
# astra_pick_rate      0.200847 -0.169751
# brimstone_pick_rate  0.277925  0.056097
# clove_pick_rate      0.056428 -0.137742
# omen_pick_rate       0.311066  0.086209
# viper_pick_rate      0.301852 -0.002041

# %%
# plot PCA result
plt.figure(figsize=(8,6))

plt.scatter(loading_df['PC1'], loading_df['PC2'])

for agent in loading_df.index:
    plt.text(
        loading_df.loc[agent,'PC1'],
        loading_df.loc[agent,'PC2'],
        agent.replace('_pick_rate',''),
        fontsize=9
    )

plt.axhline(0, color='gray', linestyle='--')
plt.axvline(0, color='gray', linestyle='--')

plt.xlabel("PC1 Loading")
plt.ylabel("PC2 Loading")
plt.title("Agent Contribution to Principal Components")

plt.show()

# %%
# check of the dataset after PCA
print("Data shape:", picks.shape)
print("Missing values:", picks.isnull().sum().sum())
# Out:
# Data shape: (29, 23)
# Missing values: 0

# %% [markdown]
# After running PCA, we double check the dataset to make sure the data looks correct and that there are no missing values.

# %% [markdown]
# The loading values show how each agent contributes to the principal components. In PC1, Omen, Viper, and Brimstone have the largest values, and they are around 0.30–0.32. However, Clove contributes much less with a value close to 0.07. Compared with PC1, the overall PC2 values vary more across agents, with Sage and Reyna showing the largest positive contributions, while agents such as Cypher and Sova have strong negative values.
#
# This suggests that PC1 is mainly influenced by several controller agents, especially Omen and Viper. In addition, agents like Jett, Raze, and Skye also show moderate positive PC1 values between 0.24 and 0.30, indicating that they contribute to the variation in team compositions as well. This also indicates that controller pick rates play a crucial role in the variation of team compositions, while other agents help differentiate strategies along the second principal component.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# <!-- > Example of how to use the checkbox, and also of how you can put in a short paragraph that discusses the way this checklist item affects your project.  Remove this paragraph and the X in the checkbox before you fill this out for your project -->
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
#  > From the Kaggle website of our dataset, the author stated that some of the China stats are missing because Chinese hosted events do not have APIs available for post-game stats. This may lead to underrepresentation from Chinese teams and bias our findings towards patterns from the other regions. To combat this limitation, we will avoid making strong claims about China where data is missing.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  > While our dataset contains publicly available professional player names, we will not link their player profile to their private identities as they are not needed for analyses. We will focus more on teams as a whole rather than looking at each player individually.
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
#  > From the Kaggle website of our dataset, the author also noted that the dataset contains missing values, placeholder team names, and inconsistencies such as two teams having the same team ID. As mentioned earlier, China has missing statistics as APIs are not publicly available. We plan to document any missing data we find and exclude rows where missing values are present.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
#  > We plan to clearly label visualizations and document any uncertainties we come across to avoid strong conclusions. For example, if there are regional differences between the Americas and China, we will make sure to clarify whether the statement was based on complete or incomplete data.
#
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#  > When performing data analysis and cleaning, we will make sure our code is well-documented so that others can easily follow along and reproduce our results. For example, since we will be looking at VCT playoff games for the years 2024 and 2025, we will clearly state these filtering decisions.
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Discussion and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? <br> Would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class

# %% [markdown]
# ### Summary
#
# - results summary
# - refer to background section and talk about how our work extended previous studies
# - what we learned from our project
#     - why it might be confusing

# %% [markdown]
# ### Limitations

# %% [markdown]
# ### Next Steps (optional)
